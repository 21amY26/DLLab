# %%
import numpy as np, pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM, GRU
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
url="https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
df = pd.read_csv(url)
data=df['Passengers'].values.reshape(-1,1)
scaler=MinMaxScaler()
data=scaler.fit_transform(data)
time_step=10
x,y = [], []
for i in range(len(data)-time_step-1):
    x.append(data[i:i+time_step,0])
    y.append(data[i+time_step,0])
x, y = np.array(x), np.array(y)

split=int(len(x)*0.8)
x_train, y_train = x[:split], y[:split]
x_test, y_test = x[split:], y[split:]

# %%
rnn = Sequential([
    SimpleRNN(50, activation='tanh', input_shape=(time_step,1)),
    Dense(1)
])

rnn.compile(optimizer='adam', loss='mse')
rnn.fit(x_train, y_train, epochs=20, batch_size=16)
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0886
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0419
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0218
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0128
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0081
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034
# Epoch 15/20
# ...

# %%
lstm=Sequential([
    LSTM(50, activation='tanh', input_shape=(time_step,1)),
    Dense(1)
])
lstm.compile(optimizer='adam', loss='mse')
lstm.fit(x_train,y_train,epochs=20, batch_size=16)
# Out:
# Epoch 1/20
# /Users/amishasingh/Documents/DLLab/stable_venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0787
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0293
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0143
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0082
# ...

# %%
gru=Sequential([
    GRU(50, activation='tanh', input_shape=(time_step,1)),
    Dense(1)
])
gru.compile(optimizer='adam', loss='mse')
gru.fit(x_train,y_train,epochs=20, batch_size=16)
# Out:
# Epoch 1/20
# /Users/amishasingh/Documents/DLLab/stable_venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0489
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0123
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0152
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0092
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0087
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0065
# ...

# %%
def predict_and_inverse(model, X):
    pred = model.predict(X)
    return scaler.inverse_transform(pred)

rnn_pred = predict_and_inverse(rnn, x_test)
lstm_pred = predict_and_inverse(lstm, x_test)
gru_pred = predict_and_inverse(gru, x_test)

y_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

def evaluate(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    return round(mse,2), round(rmse,2), round(mae,2)

print("RNN:", evaluate(y_actual, rnn_pred))
print("LSTM:", evaluate(y_actual, lstm_pred))
print("GRU:", evaluate(y_actual, gru_pred))
# Out:
# RNN: (2506.25, np.float64(50.06), 39.38)
# LSTM: (6535.88, np.float64(80.84), 65.15)
# GRU: (5242.46, np.float64(72.4), 61.73)

# %%
plt.figure(figsize=(10,6))
plt.plot(y_actual, label="Actual")
plt.plot(rnn_pred, label="RNN")
plt.plot(lstm_pred, label="LSTM")
plt.plot(gru_pred, label="GRU")
plt.legend()
plt.title("Model Comparison")
plt.show()

# %%
plt.plot(rnn.history.history['loss'], label='RNN')
plt.plot(lstm.history.history['loss'], label='LSTM')
plt.plot(gru.history.history['loss'], label='GRU')
plt.legend()
plt.title("Training Loss")
plt.show()
